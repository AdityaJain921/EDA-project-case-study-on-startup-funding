# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
startups =  pd.read_csv(r"C:\Users\LENOVO\Downloads\startup_funding.csv")
df= startups.copy()

# %%
df.CityLocation.fillna("None", inplace = True)
# df.CityLocation.dropna("None", inplace = True)
df.CityLocation.replace("bangalore", "Bangalore", inplace = True)
df.CityLocation.replace("Delhi", "New Delhi", inplace = True)
given_cities = ["Bangalore", "New Delhi", "Gurgaon", "Mumbai", "Noida"]
def func(s):
    s = str(s)
    if s != "":
        list =  s.split("/")
        for i in range(len(list)):
            if list[i].strip() in given_cities:
                return list[i].strip()

df["CityLocation"] = df["CityLocation"].apply(func)
maximum_fundings = df.CityLocation.value_counts()
labels = maximum_fundings.index
count = maximum_fundings.values
plt.pie(count, labels = labels, autopct = "%0.2f%%")
plt.title("Total Fundings")
plt.axis("equal")
plt.show()
print(maximum_fundings.index[0], maximum_fundings.values[0])
# Out:
# Bangalore 637

# %%
import csv
with open(r"C:\Users\LENOVO\Downloads\startup_funding.csv", encoding='utf8') as file_obj:
    file_data=csv.DictReader(file_obj, skipinitialspace=True)
    investors=[]
    for row in file_data:
        if not ('Undisclosed' in row['InvestorsName'] or 'undisclosed' in row['InvestorsName']):
            for i in row['InvestorsName'].split(','):
                investors.append(i.strip())
    dic=dict()
    for i in investors:
        if i in dic.keys():
            dic[i]+=1
        else:
            dic[i]=1
    x=[]
    y=[]
    for i in dic.keys():
        x.append(i)
        y.append(dic[i])
    np_x=np.array(x)
    np_y=np.array(y)
    np_x=np_x[np.argsort(np_y)]
    np_y=np.sort(np_y)
    
    np_y=np_y[::-1]
    np_x=np_x[::-1]
    plt.pie(np_y[0:6], labels= np_x[0:6], autopct = "%0.2f%%")
    plt.axis("equal")
    plt.title
    plt.show()
    for i in range(6):
        if np_x[i] != "":
            print(np_x[i], np_y[i])
# Out:
# Sequoia Capital 64
# Accel Partners 52
# Kalaari Capital 44
# SAIF Partners 41
# Indian Angel Network 40

# %%
df = startups.copy()
investorsName = df["InvestorsName"]
startupName = df["StartupName"]
df.InvestorsName.replace("Paytm Marketplace", "Paytm", inplace = True)
df.InvestorsName.replace("Flipkart.com", "Flipkart", inplace = True)
df.InvestorsName.replace(["Ola Cabs", "olacabs"], "Ola", inplace = True)
df.InvestorsName.replace(["Oyo Rooms", "oyorooms", "OyoRooms", "oyoRooms", "OYO ROOMS", "OYOROOMS"], "Oyo", inplace = True)
# print(df["InvestorsName"].values[:5]
dict = {}
for i in range(len(df.InvestorsName)):
    names = InvestorsName[i].split(",")
    for name in names:
        if df.StartupName[i] ot in dict[name]:
            dict[name] = dict[name].append
